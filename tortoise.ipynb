# %%
# Import package
import pandas as pd
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split

# %%
tortoise = pd.read_csv("tortoise.csv")

# %%
X = tortoise["Length"]
y = tortoise["Clutch"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 123)

# %%
X_test = np.asarray(X_test)
y_test = np.asarray(y_test)
plt.scatter(X_test, y_test)
plt.xlabel("Length (mm)",fontsize=14)
plt.ylabel("Clutch size",fontsize=14)
plt.plot([X_test.min(),X_test.max()],[1,1],color="red",linewidth=2)
plt.ylim([0, 14])
for i in range(len(X_test)):
    plt.plot([X_test[i],X_test[i]],[y_test[i],1],color='grey',linewidth = 2)

# %%
linModel = LinearRegression()
linModel.fit(X_train.values.reshape(-1, 1),y_train.values.reshape(-1, 1))
y_pred = np.ravel(linModel.predict(X_test.reshape(-1,1)))

# %%
plt.scatter(X_test, y_test)
plt.xlabel("Length (mm)",fontsize=14)
plt.ylabel("Clutch size",fontsize=14)
plt.plot(X_test,y_pred,color='red',linewidth=2)
plt.ylim([0, 14])
for i in range(5):
    plt.plot([X_test[i],X_test[i]],[y_test[i],y_pred[i]],color='grey',linewidth = 2)

# %%
metrics.mean_squared_error(y_test, y_pred)
# Out:
# 13.769920706476412

# %%
metrics.mean_absolute_error(y_test, y_pred)
# Out:
# 3.132264529058116

# %%
plt.scatter(X_test, y_test)
plt.xlabel("Length (mm)",fontsize=14)
plt.ylabel("Clutch size",fontsize=14)
plt.ylim([0, 14])
plt.plot([298,320],[-0.1861167*298+66.74245473,-0.1861167*320+66.74245473],color='red',linewidth=2)
for i in range(5):
    plt.plot([X_test[i],X_test[i]],[y_test[i],-0.1861167*X_test[i]+66.74245473],color='grey',linewidth = 2)

# %%
X_train = np.asarray(X_train)
y_train = np.asarray(y_train)
poly = PolynomialFeatures().fit_transform(X_train.reshape(-1,1))
poly_reg_model = LinearRegression().fit(poly,y_train)

# %%
poly_test = PolynomialFeatures().fit_transform(X_test.reshape(-1,1))
y_pred = poly_reg_model.predict(poly_test)

# %%
metrics.mean_squared_error(y_test, y_pred)
# Out:
# 7.90595691858314

# %%
metrics.mean_absolute_error(y_test, y_pred)
# Out:
# 2.6860332375257485

# %%
plt.scatter(X_test, y_test)
plt.xlabel("Length (mm)",fontsize=14)
plt.ylabel("Clutch size",fontsize=14)
x = np.linspace(X_test.min(),X_test.max(),100)
y = poly_reg_model.coef_[2]*x**2 + poly_reg_model.coef_[1]*x + poly_reg_model.intercept_
plt.plot(x,y,color='red',linewidth=2)
plt.ylim([0, 14])
for i in range(5):
    plt.plot([X_test[i],X_test[i]],[y_test[i],y_pred[i]],color='grey',linewidth = 2)

# %%
X_test = np.array(X_test)

# %%
X_test = np.append(X_test, 310)

# %%
X_test
# Out:
# array([298, 311, 320, 306, 299, 306, 310])

# %%
y_test = np.array(y_test)

# %%
y_test = np.append(y_test, 1)

# %%
y_test
# Out:
# array([11, 13,  6,  8, 12,  8,  1])

# %%
poly_test = PolynomialFeatures().fit_transform(X_test.reshape(-1,1))
y_pred = poly_reg_model.predict(poly_test)

# %%
y_pred
# Out:
# array([8.09417242, 9.87858287, 9.31961193, 9.55476247, 8.34018216,
#        9.55476247, 9.85006792])

# %%
plt.scatter(X_test, y_test)
plt.xlabel("Length (mm)",fontsize=14)
plt.ylabel("Clutch size",fontsize=14)
x = np.linspace(X_test.min(),X_test.max(),100)
y = poly_reg_model.coef_[2]*x**2 + poly_reg_model.coef_[1]*x + poly_reg_model.intercept_
plt.plot(x,y,color='red',linewidth=2)
plt.ylim([0, 14])
for i in range(7):
    plt.plot([X_test[i],X_test[i]],[y_test[i],y_pred[i]],color='grey',linewidth = 2)

# %%
metrics.mean_absolute_error(y_test, y_pred)
# Out:
# 3.5666096204277795

# %%
metrics.mean_squared_error(y_test, y_pred)
# Out:
# 17.965634808839866

# %%
linModel = LinearRegression()
linModel.fit(X_train.reshape(-1,1),y_train.reshape(-1,1))
y_pred = np.ravel(linModel.predict(X_test.reshape(-1,1)))

# %%
plt.scatter(X_test, y_test)
plt.xlabel("Length (mm)",fontsize=14)
plt.ylabel("Clutch size",fontsize=14)
plt.plot(X_test,y_pred,color='red',linewidth=2)
plt.ylim([0, 14])
for i in range(7):
    plt.plot([X_test[i],X_test[i]],[y_test[i],y_pred[i]],color='grey',linewidth = 2)

# %%
metrics.mean_absolute_error(y_test, y_pred)
# Out:
# 3.590466647580876

# %%
metrics.mean_squared_error(y_test, y_pred)
# Out:
# 17.5444369443152
