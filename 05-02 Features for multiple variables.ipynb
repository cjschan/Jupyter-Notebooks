# %%
# Load required packages
import pandas as pd
import seaborn as sns

# Import data from a .csv file
hawks = pd.read_csv('hawks.csv')
hawks
# Out:
#     Species Age   Wing  Weight  Culmen  Hallux  Tail
# 0        RT   I  385.0     920    25.7    30.1   219
# 1        RT   I  381.0     990    26.7    31.3   235
# 2        CH   I  265.0     470    18.7    23.5   220
# 3        SS   I  205.0     170    12.5    14.3   157
# 4        RT   I  412.0    1090    28.5    32.2   230
# ..      ...  ..    ...     ...     ...     ...   ...
# 886      RT   I  380.0    1525    26.0    27.6   224
# 887      SS   I  190.0     175    12.7    15.4   150
# 888      RT   I  360.0     790    21.9    27.6   211
# 889      RT   I  369.0     860    25.2    28.0   207
# 890      RT   A  199.0    1290    28.7    32.1   222
#
# [891 rows x 7 columns]

# %%
# Scatterplot with Wing and Weight
p = sns.scatterplot(data=hawks, x='Wing', y='Weight')
p.set_xlabel('Wing', fontsize=14)
p.set_ylabel('Weight', fontsize=14)
# Out:
# Text(0, 0.5, 'Weight')

# %%
# Change point color by Species
p = sns.scatterplot(data=hawks, x='Wing', y='Weight', 
                    hue='Species')
p.set_xlabel('Wing', fontsize=14)
p.set_ylabel('Wing', fontsize=14)
# Out:
# Text(0, 0.5, 'Wing')

# %%
# Change point color and shape (style) by Species
p = sns.scatterplot(data=hawks, x='Wing', y='Weight', 
                    hue='Species', style='Species')
p.set_xlabel('Wing', fontsize=14)
p.set_ylabel('Wing', fontsize=14)
# Out:
# Text(0, 0.5, 'Wing')

# %%
# Change opacity with alpha
p = sns.scatterplot(data=hawks, x='Wing', y='Weight', 
                    hue='Species', style='Species', 
                    alpha=0.5)
p.set_xlabel('Wing', fontsize=14)
p.set_ylabel('Wing', fontsize=14)
# Out:
# Text(0, 0.5, 'Wing')

# %%
# Change color palette with palette
p = sns.scatterplot(data=hawks, x='Wing', y='Weight', 
                    hue='Species', style='Species', 
                    palette='Set2')
p.set_xlabel('Wing', fontsize=14)
p.set_ylabel('Wing', fontsize=14)
# Out:
# Text(0, 0.5, 'Wing')
