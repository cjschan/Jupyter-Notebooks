# %%
import numpy as np
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
from numpy import quantile, where, random
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %%
dataframe = pd.read_csv("homes.csv")
df = dataframe[["Price","Floor"]]
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns = ["Price","Floor"])

# %%
model = DBSCAN(eps = 1, min_samples = 12).fit(df_scaled)
y_pred = model.fit_predict(df_scaled)
model_index = where(y_pred==-1)
outliers = df_scaled.loc[model_index]
plt.figure(figsize = (5,5))
plt.xlim(-3,5)
plt.ylim(-3,5)
plt.xlabel("z-scored floor size", fontsize = 14)
plt.ylabel("z-scored price", fontsize = 14)
plt.scatter(df_scaled["Floor"], df_scaled["Price"])
plt.scatter(outliers["Floor"],outliers["Price"], color='r')

# %%
df_scaled.loc[model_index]
# Out:
#        Price     Floor
# 1   2.739702  0.396200
# 3   1.071227 -2.504029
# 19 -0.146760 -2.513507
# 75  1.062884  4.386384

# %%
plt.figure(figsize = (6,5))
plt.scatter(df["Floor"], df["Price"])
plt.xlabel("Floor size (square feet)", fontsize = 14)
plt.ylabel("Price (dollars in thousands)", fontsize = 14)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
outliers = df.loc[model_index]

# %%
outliers
# Out:
#     Price  Floor
# 0   388.0  2.180
# 1   450.0  2.054
# 2   386.0  2.112
# 4   155.5  1.800
# 51  385.5  1.904
# 63  374.5  1.712
# 73  435.0  2.253

# %%
df = pd.read_csv("homes.csv")
df = df[["Price", "Floor"]]
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df))
model = DBSCAN(eps = 1, min_samples = 10).fit(df_scaled)
y_pred = model.fit_predict(df_scaled)
model_index = where(y_pred==-1)

# %%
circle1 = plt.Circle((1.062884,4.386384), 1, color='r', fill=False)
circle2 = plt.Circle((2.739702,0.396200), 1, color='r', fill=False)
circle3 = plt.Circle((1.071227,-2.504029), 1, color='r', fill=False)
circle4 = plt.Circle((-0.146760,-2.513507), 1, color='r', fill=False)
fig = plt.figure()
ax = fig.add_subplot(111)
plt.scatter(df_scaled[0], df_scaled[1])
plt.xlim(-3,4)
plt.ylim(-3.5,5.5)
ax.add_patch(circle1)
ax.add_patch(circle2)
ax.add_patch(circle3)
ax.add_patch(circle4)
ax.set_aspect('equal', adjustable='box')

# %%
outliers
# Out:
#     Price  Floor
# 0   388.0  2.180
# 1   450.0  2.054
# 2   386.0  2.112
# 4   155.5  1.800
# 21  185.0  1.860
# 24  195.0  2.112
# 45  189.5  1.906
# 51  385.5  1.904
# 63  374.5  1.712
# 73  435.0  2.253

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.scatter(df_scaled[1], df_scaled[0])
plt.xlim(-3,5)
plt.ylim(-3.5,5.5)
plt.xlabel("z scores for floor size",fontsize = 14)
plt.ylabel("z scores for price", fontsize = 14)
ax.set_aspect('equal', adjustable='box')

# %%
df_scaled
# Out:
#            0         1
# 0   1.705247  0.993306
# 1   2.739702  0.396200
# 2   1.671878  0.671058
# 3   1.071227 -2.504029
# 4  -2.173957 -0.807490
# ..       ...       ...
# 71 -0.598917  0.524151
# 72 -1.181214  0.348811
# 73  2.489430  1.339248
# 74 -0.181798 -0.518415
# 75  1.062884  4.386384
#
# [76 rows x 2 columns]

# %%
outliers
# Out:
#        Price     Floor
# 1   2.739702  0.396200
# 3   1.071227 -2.504029
# 19 -0.146760 -2.513507
# 75  1.062884  4.386384

# %%
ax1 = fig.add_subplot(211)
plt.scatter(df["Floor"], df["Price"])
plt.xlabel("Floor size (sq ft)")
plt.ylabel("Price (thousand dollars)")
# Out:
# Text(0, 0.5, 'Price (thousand dollars)')

# %%
outliers
# Out:
#     Price  Floor
# 0   388.0  2.180
# 1   450.0  2.054
# 2   386.0  2.112
# 4   155.5  1.800
# 51  385.5  1.904
# 63  374.5  1.712
# 73  435.0  2.253

# %%
outliers[1]*df.std(ddof=0)[1] + df.mean()[1]

# %%
outliers[0]*df.std(ddof=0)[0] + df.mean()[0]

# %%
df.std(ddof=0)

# %%
df.mean()

# %%
df

# %%
outliers

# %%
df

# %%
1+1

# %%
-0.146760*0.211018+1.970395

# %%
2.513507*59.934972+285.796053

# %%
-2.513507*0.211018+1.970395

# %%
-0.146760*59.934972+285.796053
