# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %%
df = pd.read_csv("/Users/cjschan/Desktop/SimData.csv")

# %%
df
# Out:
#       Male  Height Handedness  Weight         Income  HeartRate  Mindfulness  \
# 0    False      65      Right     126   70817.151524         73          9.0
# 1     True      69      Right     171  262562.808025         70          9.0
# 2     True      67      Right     164  111258.244767         80          8.0
# 3    False      66      Right     124   26948.877935         74          5.0
# 4     True      69      Right     170  723425.315806         76          8.0
# ..     ...     ...        ...     ...            ...        ...          ...
# 284   True      63      Right     156    8924.116216         81          5.0
# 285  False      67      Right     121   11914.479462         73          8.0
# 286   True      65      Right     164   13182.360665         67          8.0
# 287  False      68      Right     138   12526.373198         73          NaN
# 288  False      64       Left     129  195819.661091         79          5.0
#
#      MentalHealth
# 0             2.0
# ...

# %%
df
# Out:
#       Male  Height Handedness  Weight         Income  HeartRate  Mindfulness  \
# 0    False      65      Right     126   70817.151524         73          9.0
# 1     True      69      Right     171  262562.808025         70          9.0
# 2     True      67      Right     164  111258.244767         80          8.0
# 3    False      66      Right     124   26948.877935         74          5.0
# 4     True      69      Right     170  723425.315806         76          8.0
# ..     ...     ...        ...     ...            ...        ...          ...
# 284   True      63      Right     156    8924.116216         81          5.0
# 285  False      67      Right     121   11914.479462         73          8.0
# 286   True      65      Right     164   13182.360665         67          8.0
# 287  False      68      Right     138   12526.373198         73          NaN
# 288  False      64       Left     129  195819.661091         79          5.0
#
#      MentalHealth
# 0             2.0
# ...

# %%
model = st.linregress(df["Weight"], df["Height"])
x = np.linspace(85, 200, 100)
y = model[0]*x + model[1]
plt.plot(x, y, "-r", linewidth="2")
plt.scatter(df.Weight, df.Height)
plt.xlabel('Weight (lbs)', fontsize=14)
plt.ylabel('Height (in)',fontsize=14)
plt.show()

# %%
plt.hist(df["Income"], range = [df["Income"].min(),df["Income"].max()])
plt.xlabel('Income', fontsize=14)
plt.ylabel('Counts',fontsize=14)
# Out:
# Text(0, 0.5, 'Counts')

# %%
print(df.describe())
# Out:
#            Height      Weight        Income   HeartRate  Mindfulness  \
# count  289.000000  289.000000  2.590000e+02  289.000000   281.000000
# mean    67.069204  150.761246  1.795092e+05   75.297578     6.597865
# std      1.929860   21.974300  3.981796e+05    4.931619     1.578379
# min     63.000000   93.000000  6.167775e+02   61.000000     2.000000
# 25%     66.000000  131.000000  2.685318e+04   72.000000     6.000000
# 50%     67.000000  151.000000  6.527641e+04   75.000000     7.000000
# 75%     68.000000  170.000000  1.890698e+05   79.000000     8.000000
# max     73.000000  196.000000  5.209708e+06   88.000000    10.000000
#
#        MentalHealth
# count    287.000000
# mean       5.114983
# std        1.545584
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        6.000000
# max        9.000000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Male          289 non-null    bool
#  1   Height        289 non-null    int64
#  2   Handedness    289 non-null    object
#  3   Weight        289 non-null    int64
#  4   Income        259 non-null    float64
#  5   HeartRate     289 non-null    int64
#  6   Mindfulness   281 non-null    float64
#  7   MentalHealth  287 non-null    float64
# dtypes: bool(1), float64(3), int64(3), object(1)
# memory usage: 16.2+ KB
# None

# %%
df.corr()
# Out:
#                   Male    Height    Weight    Income  HeartRate  Mindfulness  \
# Male          1.000000  0.480334  0.860559  0.058598   0.061000     0.071030
# Height        0.480334  1.000000  0.584344  0.024716  -0.029169     0.121932
# Weight        0.860559  0.584344  1.000000  0.052303  -0.046314     0.064549
# Income        0.058598  0.024716  0.052303  1.000000   0.061497     0.051299
# HeartRate     0.061000 -0.029169 -0.046314  0.061497   1.000000    -0.020481
# Mindfulness   0.071030  0.121932  0.064549  0.051299  -0.020481     1.000000
# MentalHealth  0.053137 -0.009835  0.058394 -0.065814   0.052518    -0.045603
#
#               MentalHealth
# Male              0.053137
# Height           -0.009835
# Weight            0.058394
# Income           -0.065814
# HeartRate         0.052518
# Mindfulness      -0.045603
# MentalHealth      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Male          289 non-null    bool
#  1   Height        289 non-null    int64
#  2   Handedness    289 non-null    object
#  3   Weight        289 non-null    int64
#  4   Income        259 non-null    float64
#  5   HeartRate     289 non-null    int64
#  6   Mindfulness   281 non-null    float64
#  7   MentalHealth  287 non-null    float64
# dtypes: bool(1), float64(3), int64(3), object(1)
# memory usage: 16.2+ KB

# %%
df = df[["Height", "Weight", "Income", "Handedness", "HeartRate"]]
df.columns = ["Height", "Weight", "Income", "Handedness", "Heart rate"]

# %%
import seaborn as sns

# %%
ax = sns.boxplot(x="Handedness", y="Heart rate", data = df, palette="Paired")
ax.set_xlabel("Handedness", fontsize = 14)
ax.set_ylabel("Heart rate", fontsize = 14)
# Out:
# Text(0, 0.5, 'Heart rate')

# %%
df = df[["Height","Weight","Income","Heart rate"]]

# %%
plt.hist(df["Height"], range = [df["Height"].min(),df["Height"].max()])
plt.xlabel("Height", fontsize=14)
plt.ylabel('Counts',fontsize=14)
# Out:
# Text(0, 0.5, 'Counts')

# %%
plt.hist(df["Weight"], range = [df["Weight"].min(),df["Weight"].max()])
plt.xlabel("Weight", fontsize=14)
plt.ylabel('Counts',fontsize=14)
# Out:
# Text(0, 0.5, 'Counts')

# %%
plt.hist(df["Income"], range = [df["Income"].min(),df["Income"].max()])
plt.xlabel("Income", fontsize=14)
plt.ylabel('Counts',fontsize=14)
# Out:
# Text(0, 0.5, 'Counts')

# %%
plt.hist(df["HeartRate"], range = [df["HeartRate"].min(),df["HeartRate"].max()])
plt.xlabel("Heart rate", fontsize=14)
plt.ylabel('Counts',fontsize=14)
# Out:
# Text(0, 0.5, 'Counts')

# %%
import random

# %%
x = np.random.f(1, 48,size = 100)

# %%
plt.hist(x)
plt.xlabel("Age", fontsize=14)
plt.ylabel('Counts',fontsize=14)
# Out:
# Text(0, 0.5, 'Counts')

# %%
y = np.random.uniform(3,25,958)

# %%
plt.hist(y)
plt.xlabel("Smiling times", fontsize=14)
plt.ylabel('Counts',fontsize=14)
# Out:
# Text(0, 0.5, 'Counts')

# %%
x = np.array(range(50))
y = x + np.random.randint(0,30,50)
plt.figure(figsize=(4, 4))
plt.scatter(x, y)

# %%
x = np.array(range(50))
y = -2*x + np.random.randint(0,30,50) + 150
plt.figure(figsize=(4, 4))
plt.scatter(x, y)

# %%
x = [random.randint(1, 50) for n in range(100)]
y = [random.randint(1, 50) for n in range(100)]
plt.figure(figsize=(4, 4))
plt.scatter(x, y)
plt.show()

# %%
df2 = pd.read_csv("/Users/cjschan/Desktop/Gas Usage Vs Temp - Data.csv")

# %%
df2.columns
# Out:
# Index(['Date', 'Gas used\n(Therms)', 'Low (F)', 'Average (F)', 'High (F)',
#        'Solar\nproduction\n(kWh)', 'Fire length\n(Hours)', 'Away (Hrs)',
#        'Panels uncovered\n(Proportion free)', 'Electric\nconsumption\n(kWh)',
#        'Hot water power (kWh)', 'Have\nguests', 'Unnamed: 12'],
#       dtype='object')

# %%
df2.columns = ["Date", "Gas used", "Low temp", 
               "Average temp", "High temp", "Solar production", 
               "Fire length", "Away", "Panels uncovered", "Energy consumption",
              "Hot water power", "Have guests", "Notes"]

# %%
df2
# Out:
#                              Date  Gas used  Low temp  Average temp  \
# 0           Sunday, March 6, 2022      1.62        30         33.12
# 1         Saturday, March 5, 2022      1.66        40         50.51
# 2           Friday, March 4, 2022      2.14        26         35.50
# 3         Thursday, March 3, 2022      0.99        26         28.33
# 4        Wednesday, March 2, 2022      0.82        31         40.92
# ..                            ...       ...       ...           ...
# 389  Wednesday, February 10, 2021      5.02        -3          3.08
# 390     Tuesday, February 9, 2021      4.40        -9         -2.33
# 391      Monday, February 8, 2021      6.42        -7         -0.22
# 392      Sunday, February 7, 2021      6.22       -17         -8.62
# 393    Saturday, February 6, 2021      5.34       -11         -0.46
#
#      High temp  Solar production  Fire length  Away  Panels uncovered  \
# 0           49             4.408          0.0   2.0               1.0
# ...

# %%
plt.scatter(df2["Low temp"],df2["High temp"])
plt.xlabel("Low temperature (°F)", fontsize=14)
plt.ylabel('High temperature (°F)',fontsize=14)
# Out:
# Text(0, 0.5, 'High temperature (°F)')

# %%
plt.scatter(df2["Average temp"],df2["Energy consumption"])
plt.xlabel("Average temperature (°F)", fontsize=14)
plt.ylabel('Energy consumption (kWH)',fontsize=14)
# Out:
# Text(0, 0.5, 'Energy consumption (kWH)')

# %%
df2 = df2[["Gas used","Low temp","High temp", "Average temp","Electric consumption"]]

# %%
df2.corr()
# Out:
#                       Gas used  Low temp  High temp  Average temp  \
# Gas used              1.000000 -0.884516  -0.897509     -0.900986
# Low temp             -0.884516  1.000000   0.956211      0.985519
# High temp            -0.897509  0.956211   1.000000      0.987941
# Average temp         -0.900986  0.985519   0.987941      1.000000
# Electric consumption  0.585655 -0.471414  -0.472467     -0.477127
#
#                       Electric consumption
# Gas used                          0.585655
# Low temp                         -0.471414
# High temp                        -0.472467
# Average temp                     -0.477127
# Electric consumption              1.000000

# %%
pd.plotting.scatter_matrix(df2)
# Out:
# array([[<AxesSubplot:xlabel='Gas used', ylabel='Gas used'>,
#         <AxesSubplot:xlabel='Low temp', ylabel='Gas used'>,
#         <AxesSubplot:xlabel='High temp', ylabel='Gas used'>,
#         <AxesSubplot:xlabel='Average temp', ylabel='Gas used'>,
#         <AxesSubplot:xlabel='Electric consumption', ylabel='Gas used'>],
#        [<AxesSubplot:xlabel='Gas used', ylabel='Low temp'>,
#         <AxesSubplot:xlabel='Low temp', ylabel='Low temp'>,
#         <AxesSubplot:xlabel='High temp', ylabel='Low temp'>,
#         <AxesSubplot:xlabel='Average temp', ylabel='Low temp'>,
#         <AxesSubplot:xlabel='Electric consumption', ylabel='Low temp'>],
#        [<AxesSubplot:xlabel='Gas used', ylabel='High temp'>,
#         <AxesSubplot:xlabel='Low temp', ylabel='High temp'>,
#         <AxesSubplot:xlabel='High temp', ylabel='High temp'>,
#         <AxesSubplot:xlabel='Average temp', ylabel='High temp'>,
#         <AxesSubplot:xlabel='Electric consumption', ylabel='High temp'>],
# ...

# %%
sm = pd.plotting.scatter_matrix(df2, diagonal = 'kde')
for subaxis in sm:
    for ax in subaxis:
        ax.xaxis.set_ticks([])
        ax.yaxis.set_ticks([])
        ax.set_ylabel("")
        ax.set_xlabel("")
pic = sm[0][0].get_figure()  
pic.savefig("MyScatter.png")
