# %%
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import squareform
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %%
cytochrome = pd.read_csv('cytochrome.csv', header=None, usecols=range(1,14))

differences = squareform(cytochrome)
matrix = linkage(differences)
species = ["Human", "Monkey", "Horse", "Cow", 
           "Dog", "Whale", "Rabbit", "Kangaroo", 
           "Chicken", "Penguin", "Duck", "Turtle", "Frog"]

# %%
dendrogram(matrix, labels=species, leaf_rotation = 90)
plt.ylabel("Amino acid differences", fontsize = 14)
plt.yticks(np.arange(0, 11, step=1))
plt.xlabel("Species", fontsize = 14)
plt.show()

# %%
pd.DataFrame(data = cytochrome.to_numpy(), 
                  index = species, 
                  columns = species)
# Out:
#           Human  Monkey  Horse  Cow  Dog  Whale  Rabbit  Kangaroo  Chicken  \
# Human         0       1     12   10   11     10       9        10       13
# Monkey        1       0     11    9   10      9       8        11       12
# Horse        12      11      0    3    6      5       6         7       11
# Cow          10       9      3    0    3      2       4         6        9
# Dog          11      10      6    3    0      3       5         7       10
# Whale        10       9      5    2    3      0       2         6        9
# Rabbit        9       8      6    4    5      2       0         6        8
# Kangaroo     10      11      7    6    7      6       6         0       12
# Chicken      13      12     11    9   10      9       8        12        0
# Penguin      14      13     13   11   11     10       9        11        3
# Duck         11      10     10    8    8      7       6        10        3
# ...
