# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
import random
random.seed(1234)
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %%
data = pd.read_csv("Mall_Customers.csv")

# %%
data.head()
# Out:
#    Gender  Age  Income  Spending_Score
# 0    Male   19      15              39
# 1    Male   21      15              81
# 2  Female   20      16               6
# 3  Female   23      16              77
# 4  Female   31      17              40

# %%
model = KMeans(n_clusters=5)
clusters = model.fit_predict(data.iloc[:,1:])
data["label"] = clusters

# %%
orange = '#E68142'
blue = '#5780DC'
green = '#1EC81E'
yellow = '#FFD364'
lightblue = '#B0D6FB'
purple = '#8424AC'
brown = '#886441'
grey = '#939292'
transparent = 'rgba(0,0,0,0)'

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data.Age[data.label == 0], data["Income"][data.label == 0], data["Spending_Score"][data.label == 0], c='orange', s=60)
ax.scatter(data.Age[data.label == 1], data["Income"][data.label == 1], data["Spending_Score"][data.label == 1], c='blue', s=60)
ax.scatter(data.Age[data.label == 2], data["Income"][data.label == 2], data["Spending_Score"][data.label == 2], c='purple', s=60)
ax.scatter(data.Age[data.label == 3], data["Income"][data.label == 3], data["Spending_Score"][data.label == 3], c='green', s=60)
ax.scatter(data.Age[data.label == 4], data["Income"][data.label == 4], data["Spending_Score"][data.label == 4], c='lightblue', s=60)
ax.view_init(-140, 60)
plt.xlabel("Age")
plt.ylabel("Income (dollars in thousands)")
ax.set_zlabel("Spending Score (1-100)")
plt.show()

# %%
plt.scatter(data["Income"][data.label == 0], data.Age[data.label == 0], c='orange', s=60)
plt.scatter(data["Income"][data.label == 1], data.Age[data.label == 1], c='lightblue', s=60)
plt.scatter(data["Income"][data.label == 2], data.Age[data.label == 2], c='purple', s=60)
plt.scatter(data["Income"][data.label == 3], data.Age[data.label == 3], c='green', s=60)
plt.scatter(data["Income"][data.label == 4], data.Age[data.label == 4], c='blue', s=60)
plt.xlabel("Income (dollars in thousands)", fontsize = 14)
plt.ylabel("Age", fontsize = 14)
# Out:
# Text(0, 0.5, 'Age')

# %%
c = ['blue', 'orange', 'red','purple','green']
plt.scatter(data.Age[data.label == 0], data["Spending_Score"][data.label == 0], c='orange', s=60)
plt.scatter(data.Age[data.label == 1], data["Spending_Score"][data.label == 1], c='blue', s=60)
plt.scatter(data.Age[data.label == 2], data["Spending_Score"][data.label == 2], c='purple', s=60)
plt.scatter(data.Age[data.label == 3], data["Spending_Score"][data.label == 3], c='green', s=60)
plt.scatter(data.Age[data.label == 4], data["Spending_Score"][data.label == 4], c='lightblue', s=60)
plt.xlabel("Age", fontsize = 14)
plt.ylabel("Spending score (1-100)", fontsize = 14)
# Out:
# Text(0, 0.5, 'Spending score (1-100)')

# %%
c = ['blue', 'orange', 'red','purple','green']
plt.scatter(data.Income[data.label == 0], data["Spending_Score"][data.label == 0], c='orange', s=60)
plt.scatter(data.Income[data.label == 1], data["Spending_Score"][data.label == 1], c='lightblue', s=60)
plt.scatter(data.Income[data.label == 2], data["Spending_Score"][data.label == 2], c='purple', s=60)
plt.scatter(data.Income[data.label == 3], data["Spending_Score"][data.label == 3], c='green', s=60)
plt.scatter(data.Income[data.label == 4], data["Spending_Score"][data.label == 4], c='blue', s=60)
plt.xlabel("Income (dollars in thousands)", fontsize = 14)
plt.ylabel("Spending score (1-100)", fontsize = 14)
# Out:
# Text(0, 0.5, 'Spending score (1-100)')
