# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
housing = pd.read_csv('txhousing.csv')

# %%
housing
# Out:
#                      city  year  month  sales      volume  median  listings  \
# 0                 Abilene  2015      6    260    41396230  141500       965
# 1                Amarillo  2015      6    342    61748196  152100      1213
# 2               Arlington  2015      6    522   105881452  180000       682
# 3                  Austin  2015      6   3301  1086689918  270200      7419
# 4                Bay Area  2015      6    780   182248573  200700      2116
# 5                Beaumont  2015      6    296    48007961  145200      1567
# 6         Brazoria County  2015      6    137    25772571  173100       285
# 7             Brownsville  2015      6     82    11833474  115000       744
# 8   Bryan-College Station  2015      6    403    84025416  187400       939
# 9           Collin County  2015      6   1789   614959441  300400      2314
# 10         Corpus Christi  2015      6    493   104904076  189600      2133
# ...

# %%
X = housing[['sales']]
y = housing[['median']]

# %%
# Create training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# Scale the input features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
y_train = scaler.fit_transform(y_train)

# %%
# Initialize and fit a linear svr model to training data
svr_lin = SVR(kernel='poly', degree=2, C = 0.1, epsilon = 1.1)
svr_lin.fit(np.reshape(X_train,(-1,1)), np.ravel(y_train))
# Out:
# SVR(C=0.1, degree=2, epsilon=1.1, kernel='poly')

# %%
np.linspace(0.1, 0.4, 6)
# Out:
# array([0.1 , 0.16, 0.22, 0.28, 0.34, 0.4 ])

# %%
svr_lin.predict(np.reshape(np.random.normal(0, 1, 5),(-1,1)))
# Out:
# array([0.11619683, 0.57148103, 0.19536741, 0.11551453, 0.25438376])

# %%
np.random.normal(0, 1, 20)
# Out:
# array([-1.11211833, -0.35207361, -0.212809  , -0.19045265,  0.12371574,
#        -0.79600783,  0.59699675, -0.83555971, -1.20767068,  0.82911875,
#         0.37247012,  1.09836702, -0.80923144, -0.58447562,  0.23231632,
#         0.82718465,  0.92918172,  0.17580246, -1.47332762, -0.53984807])

# %%
print(svr_lin)
# Out:
# SVR(C=0.1, degree=2, epsilon=1.1, kernel='poly')

# %%
svr_lin.predict(np.reshape([-1.11211833, -0.35207361, -0.212809  , -0.19045265,  0.12371574,-0.79600783,  0.59699675, -0.83555971, -1.20767068,  0.82911875,
        0.37247012,  1.09836702, -0.80923144, -0.58447562,  0.23231632,
        0.82718465,  0.92918172,  0.17580246, -1.47332762, -0.53984807],(-1,1))
# Out:
#   Input In [14]
#     0.82718465,  0.92918172,  0.17580246, -1.47332762, -0.53984807],(-1,1))
#                                                                            ^
# SyntaxError: unexpected EOF while parsing

# %%
array = [1.37460487,-1.38276878,2.0829424,0.21345689, -1.21033951,0.18506318,0.56063398,0.42868309,-1.38872698,0.01743677,-1.37647729,-0.68148206,-0.1794263 ,-0.40175439,  0.96515971,-2.21100338, -0.18564737,  0.06678801,  0.40305024,  0.17529709]

# %%
svr_lin.predict(np.reshape(array,(-1,1)))
# Out:
# array([0.25059029, 0.2523508 , 0.44212647, 0.10637963, 0.21738253,
#        0.10549469, 0.12739734, 0.11718817, 0.25364223, 0.10284002,
#        0.25099315, 0.1391367 , 0.105334  , 0.11543927, 0.17566813,
#        0.48513116, 0.10551162, 0.10316509, 0.11552084, 0.10521945])
