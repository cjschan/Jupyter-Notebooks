# %%
import numpy as np

# %%
s = np.random.normal(0, .1, 1000)

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %config InlineBackend.figure_formats = ['svg']
s = np.random.normal(0, .1, 1000)
plt.xlim(-1,1)
plt.ylim(0,5)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Lower standard deviation")
count, bins, ignored = plt.hist(s, 30, density=True)

# %%
s = np.random.normal(0, .3, 1000)
plt.xlim(-1,1)
plt.ylim(0,5)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Higher standard deviation")
count, bins, ignored = plt.hist(s, 30, density=True)

# %%
s = np.random.normal(0, .15, 1000)
plt.xlim(-0.6,0.6)
plt.ylim(0,5)
count, bins, ignored = plt.hist(s, 30, density=True)

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = sns.boxplot(x="day", y="total_bill", data=tips)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.xlim(0,60)
sns.boxplot(tips[tips.day == "Thur"]["total_bill"])

# %%
plt.xlim(0,60)
sns.boxplot(tips[tips.day == "Sat"]["total_bill"])

# %%
plt.xlim(0,60)
sns.boxplot(tips[tips.day == "Fri"]["total_bill"])

# %%
# %config InlineBackend.figure_formats = ['svg']
s = np.random.normal(0, 1, 200)
plt.xlim(-4,4)
plt.ylim(0,0.7)
count, bins, ignored = plt.hist(s, 30, density=True)

# %%
# %config InlineBackend.figure_formats = ['svg']
s = np.random.normal(0, 0.2, 50)
plt.xlim(-4,4)
plt.ylim(0,0.7)
count, bins, ignored = plt.hist(s, 30, density=True)
