# %%
import pandas as pd
import matplotlib_inline.backend_inline
import matplotlib.pyplot as plt
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/yankev/test/master/life-expectancy-per-GDP-2007.csv")

# %%
df = df[df["continent"] == "Americas"]

# %%
import seaborn as sns

# %%
df.head()
# Out:
#    Unnamed: 0 continent                                       country  \
# 0           0  Americas  Country: Argentina<br>Population: 40301927.0
# 1           1  Americas     Country: Bolivia<br>Population: 9119152.0
# 2           2  Americas    Country: Brazil<br>Population: 190010647.0
# 3           3  Americas     Country: Canada<br>Population: 33390141.0
# 4           4  Americas      Country: Chile<br>Population: 16284741.0
#
#      gdp_percap  life_exp
# 0  12779.379640    75.320
# 1   3822.137084    65.554
# 2   9065.800825    72.390
# 3  36319.235010    80.653
# 4  13171.638850    78.553

# %%
ax = sns.boxplot(x = "life_exp", data = df)
ax.set_xlabel("Life expectancy (years)", fontsize = 14)
# Out:
# Text(0.5, 0, 'Life expectancy (years)')

# %%
ax = sns.boxplot(x = "gdp_percap", data = df)
ax.set_xlabel("GDP per capita (dollars)", fontsize = 14)
# Out:
# Text(0.5, 0, 'GDP per capita (dollars)')

# %%
ax = sns.distplot(x = df["life_exp"], bins = 4)
ax.set_xlabel("Life expectancy (years)", fontsize = 14)
ax.set_ylabel("Density", fontsize = 14)
# Out:
# /Users/cjschan/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Density')

# %%
World2007[World2007["continent"]=="Africa"]["gdpPercap"].median()
# Out:
# 1452.2670775000001

# %%
df = World2007[World2007["continent"]=="Africa"].describe()

# %%
df.round(2)
# Out:
#          year  lifeExp           pop  gdpPercap  iso_num
# count    52.0    52.00  5.200000e+01      52.00    52.00
# mean   2007.0    54.81  1.787576e+07    3089.03   458.83
# std       0.0     9.63  2.491773e+07    3618.16   249.37
# min    2007.0    39.61  1.995790e+05     277.55    12.00
# 25%    2007.0    47.83  2.909226e+06     862.95   231.75
# 50%    2007.0    52.93  1.009331e+07    1452.27   460.00
# 75%    2007.0    59.44  1.936365e+07    3993.50   688.00
# max    2007.0    76.44  1.350312e+08   13206.48   894.00

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
World2007[World2007["continent"]=="Europe"].describe()
# Out:
#          year  lifeExp         pop  gdpPercap  iso_num
# count   30.00    30.00       30.00      30.00    30.00
# mean  2007.00    77.65 19536617.63   25054.48   427.63
# std      0.00     2.98 23624743.66   11800.34   258.96
# min   2007.00    71.78   301931.00    5937.03     8.00
# 25%   2007.00    75.03  4780559.50   14811.90   217.50
# 50%   2007.00    78.61  9493598.00   28054.07   376.00
# 75%   2007.00    79.81 20849695.25   33817.96   676.50
# max   2007.00    81.76 82400996.00   49357.19   826.00

# %%
World2007[World2007["continent"]=="Asia"].describe()
# Out:
#          year  lifeExp           pop  gdpPercap  iso_num
# count   33.00    33.00         33.00      33.00    33.00
# mean  2007.00    70.73  115513752.33   12473.03   404.67
# std      0.00     7.96  289673399.13   14154.94   227.85
# min   2007.00    43.83     708573.00     944.00     4.00
# 25%   2007.00    65.48    6426679.00    2452.21   275.00
# 50%   2007.00    72.40   24821286.00    4471.06   400.00
# 75%   2007.00    75.64   69453570.00   22316.19   524.00
# max   2007.00    82.60 1318683096.00   47306.99   887.00

# %%
df
# Out:
#          year  lifeExp          pop  gdpPercap  iso_num
# count   52.00    52.00        52.00      52.00    52.00
# mean  2007.00    54.81  17875763.31    3089.03   458.83
# std      0.00     9.63  24917726.17    3618.16   249.37
# min   2007.00    39.61    199579.00     277.55    12.00
# 25%   2007.00    47.83   2909226.50     862.95   231.75
# 50%   2007.00    52.93  10093310.50    1452.27   460.00
# 75%   2007.00    59.44  19363654.50    3993.50   688.00
# max   2007.00    76.44 135031164.00   13206.48   894.00

# %%
df = World2007.describe()

# %%
World2007[World2007["continent"]=="Asia"].describe()
# Out:
#          year  lifeExp           pop  gdpPercap  iso_num
# count   33.00    33.00         33.00      33.00    33.00
# mean  2007.00    70.73  115513752.33   12473.03   404.67
# std      0.00     7.96  289673399.13   14154.94   227.85
# min   2007.00    43.83     708573.00     944.00     4.00
# 25%   2007.00    65.48    6426679.00    2452.21   275.00
# 50%   2007.00    72.40   24821286.00    4471.06   400.00
# 75%   2007.00    75.64   69453570.00   22316.19   524.00
# max   2007.00    82.60 1318683096.00   47306.99   887.00

# %%
df = World2007[["country","continent"]].groupby('continent').count()

# %%
df2 = df.iloc[:5,]

# %%
World2007[World2007["continent"]=="Asia"].describe()
# Out:
#            country
# continent
# Africa          52
# Americas        25
# Asia            33
# Europe          30
# Oceania          2

# %%
df.insert(1, "Relative frequency", df["Count"]/142, True)

# %%
df
# Out:
#            Count  Proportion
# continent
# Africa        52        0.37
# Americas      25        0.18
# Asia          33        0.23
# Europe        30        0.21
# Oceania        2        0.01

# %%
df2 = pd.read_csv('country_complete.csv')
# [1] Simple count
sns.countplot(x='Continent', data=df2)
plt.show()
# [1B] By percent
pct = df2['Continent'].value_counts(normalize=True).reset_index()
sns.barplot(x='Continent',data=pct)
plt.show()

# %%
sns.histplot(data=df2, x="Continent", stat="density")
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Density'>

# %%
tips = sns.load_dataset("tips")
sns.histplot(data=df2, x="Continent", hue="Emissions range", shrink=.8, multiple="dodge")
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Count'>
