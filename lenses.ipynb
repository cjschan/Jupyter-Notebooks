# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn import tree
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %%
data = pd.read_csv("lenses.csv")
data = data.to_numpy()
X = data[:, :-1]
y = data[:, -1]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/hs/1vg7k3hs1_34vpfdct382twh0000gn/T/ipykernel_26548/104561194.py in <module>
# ----> 1 data = pd.read_csv("lenses.csv")
#       2 data = data.to_numpy()
#       3 X = data[:, :-1]
#       4 y = data[:, -1]
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
model = DecisionTreeClassifier(criterion = "gini", min_samples_split = 2, min_samples_leaf = 1)
fitModel = model.fit(X, y)

# %%
colNames = ["age", "spec-prescrip", "astigmatism", "tear-prod-rate"]

# %%
tree.plot_tree(model, feature_names = feature_names,rounded = True, proportion = False, 
                label='all',
                precision = 2, filled = True)
# %config InlineBackend.figure_formats = ['svg']
