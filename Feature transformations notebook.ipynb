# %%
import sklearn.preprocessing
from sklearn.preprocessing import PowerTransformer
import statsmodels.api as sm
import statsmodels.formula.api as sms
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %%
pt = PowerTransformer

# load the dataset
df_animals = sm.datasets.get_rdataset(dataname='Animals', package='MASS').data

animals = df_animals.values

# response variable
Y = df_animals['brain']

# predictor variable
x = df_animals['body']

# %%
plt.hist(x)
plt.xlabel('x', size=14)
plt.ylabel('Count', size=14)
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.hist(np.log(x))
plt.xlabel('log(x)', size=14)
plt.ylabel('Count', size=14)
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.hist(np.sqrt(x))
plt.xlabel('sqrt(x)', size=14)
plt.ylabel('Count', size=14)
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.hist(np.reciprocal(x))
plt.xlabel('reciprocal(x)', size=14)
plt.ylabel('Count', size=14)
# Out:
# Text(0, 0.5, 'Count')
